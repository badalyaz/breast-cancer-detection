# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os
import pickle
import numpy
from glob import glob
from tqdm import tqdm

# %%
    with open('/home/server/other_projects/breast_cancer/DATA_PATH/Data/SFUniversity/Annotations.pickle', 'rb') as handle:
        res = pickle.load(handle)

# %%
    plt_count = (1,1)
    plt.figure(figsize=(30,30))

# %%
img_ind = 20
for i in range(plt_count[0]):
    for j in range(plt_count[1]):            
        key = list(res.keys())[img_ind] 

        while (not os.path.exists(res[key]["image_path"])):
            img_ind+=1
            key = list(res.keys())[img_ind]       

        img = plt.imread(res[key]["image_path"])             
        ax = plt.subplot2grid(plt_count, (i,j))
        ax.tick_params(left=False,bottom=False,labelleft=False,labelbottom=False)   
        ax.set_title(key, fontsize=5)            
        ax.imshow(img)

        if "ABNORMALITY_1" in res[key].keys():
            bbox = res[key]["ABNORMALITY_1"]["masks"][0]["bbox"]

            rect = patches.Rectangle((bbox[0],bbox[1]),bbox[2]-bbox[0],bbox[3]-bbox[1],
                                      linewidth=1, edgecolor='r', facecolor='none')
        #add patches
            ax.add_patch(rect)
            mask = (res[key]["ABNORMALITY_1"]["masks"][0]["mask_x"],res[key]["ABNORMALITY_1"]["masks"][0]["mask_y"])
            ax.plot(mask[0],mask[1],color="y")
        print(f"on image {key}.png")
        # print(bbox)
        img_ind+=1
plt.show()
# Out:
# on image B_3246_1.RIGHT_MLO.png
# on image B_3246_1.LEFT_CC.png
# on image B_3246_1.LEFT_MLO.png
# on image B_3246_1.RIGHT_CC.png
# on image B_3227_1.RIGHT_MLO.png
# on image B_3227_1.LEFT_MLO.png
# on image B_3227_1.RIGHT_CC.png
# on image B_3227_1.LEFT_CC.png
# on image B_3178_1.LEFT_CC.png
# on image B_3178_1.RIGHT_MLO.png
# on image B_3178_1.RIGHT_CC.png
# on image B_3178_1.LEFT_MLO.png
# on image B_3250_1.RIGHT_MLO.png
# on image B_3250_1.RIGHT_CC.png
# on image B_3250_1.LEFT_CC.png
# on image B_3250_1.LEFT_MLO.png
# on image B_3217_1.RIGHT_MLO.png
# on image B_3217_1.LEFT_MLO.png
# on image B_3217_1.LEFT_CC.png
# on image B_3217_1.RIGHT_CC.png
# on image B_3165_1.LEFT_MLO.png
# on image B_3165_1.RIGHT_MLO.png
# on image B_3165_1.RIGHT_CC.png
# on image B_3165_1.LEFT_CC.png
# on image B_3184_1.RIGHT_MLO.png
